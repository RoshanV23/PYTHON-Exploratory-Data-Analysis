# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Vrattika'

# %%
os.chdir('F:\\DataScience')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline

# %%
imdb = pd.read_excel('DATASETS/IMDBdataset.xlsx')

# %%
imdb.shape
# Out:
# (3891, 30)

# %%
imdb.head()
# Out:
#   Clr_Bw                                Movie_Title  Genre1  \
# 0  Color                                    Avatar   Action
# 1  Color  Pirates of the Caribbean: At World's End   Action
# 2  Color                                   Spectre   Action
# 3  Color                     The Dark Knight Rises   Action
# 4  Color                               John Carter   Action
#
#                             Genre2  Genre_Nos     Actor_1_Name  \
# 0  Action|Adventure|Fantasy|Sci-Fi          4      CCH Pounder
# 1         Action|Adventure|Fantasy          3      Johnny Depp
# 2        Action|Adventure|Thriller          3  Christoph Waltz
# 3                  Action|Thriller          2        Tom Hardy
# 4          Action|Adventure|Sci-Fi          3     Daryl Sabara
#
#        Actor_2_Name          Actor_3_Name           Director  Title_Year  ...  \
# 0  Joel David Moore             Wes Studi      James Cameron        2009  ...
# ...

# %%
imdb.tail()
# Out:
#      Clr_Bw         Movie_Title       Genre1  \
# 3886  Color             Primer         Drama
# 3887  Color             Cavite      Thriller
# 3888  Color        El Mariachi        Action
# 3889  Color          Newlyweds        Comedy
# 3890  Color  My Date with Drew   Documentary
#
#                                    Genre2  Genre_Nos     Actor_1_Name  \
# 3886                Drama|Sci-Fi|Thriller          3    Shane Carruth
# 3887                             Thriller          1      Ian Gamazon
# 3888  Action|Crime|Drama|Romance|Thriller          5  Carlos Gallardo
# 3889                         Comedy|Drama          2     Kerry Bish̩
# 3890                          Documentary          1      John August
#
#             Actor_2_Name     Actor_3_Name          Director  Title_Year  ...  \
# 3886      David Sullivan     Casey Gooden     Shane Carruth        2004  ...
# 3887     Edgar Tancangco        Quynn Ton  Neill Dela Llana        2005  ...
# ...

# %%
imdb.columns
# Out:
# Index(['Clr_Bw', 'Movie_Title', 'Genre1', 'Genre2', 'Genre_Nos',
#        'Actor_1_Name', 'Actor_2_Name', 'Actor_3_Name', 'Director',
#        'Title_Year', 'Duration', 'IMDB_Score', 'Budget', 'Gross', 'Language',
#        'Country', 'Facenumber_in_Poster', 'Actor_1_FB_Likes',
#        'Actor_2_FB_Likes', 'Actor_3_FB_Likes', 'Director_FB_Likes',
#        'Cast_Total_FB_Likes', 'LMovie_FB_likes', 'No_Critic_reviews',
#        'User_Reviews', 'Users_Vote', 'Content_Rating', 'Aspect_Ratio',
#        'Plot_Keywords', 'Movie_IMDB_link'],
#       dtype='object')

# %%
imdb.columns = ['ScreenColor', 'Title', 'Genre1', 'Genre2', 'Genre_Nos',
       'Actor1_Name', 'Actor2_Name', 'Actor3_Name', 'Director',
       'Year', 'Duration', 'IMDB_Score', 'BudgetMillions', 'GrossMillions', 'Language',
       'Country', 'Facenumber_in_Poster', 'Actor1_FBLikes',
       'Actor2_FBLikes', 'Actor3_FBLikes', 'Director_FBLikes',
       'CastTotal_FBLikes', 'LMovie_FBlikes', 'No_CriticReviews',
       'UserReviews', 'UsersVote', 'ContentRating', 'AspectRatio',
       'Plot_Keywords', 'Movielink' ]

# %%
imdb.head()
# Out:
#   ScreenColor                                      Title  Genre1  \
# 0       Color                                    Avatar   Action
# 1       Color  Pirates of the Caribbean: At World's End   Action
# 2       Color                                   Spectre   Action
# 3       Color                     The Dark Knight Rises   Action
# 4       Color                               John Carter   Action
#
#                             Genre2  Genre_Nos      Actor1_Name  \
# 0  Action|Adventure|Fantasy|Sci-Fi          4      CCH Pounder
# 1         Action|Adventure|Fantasy          3      Johnny Depp
# 2        Action|Adventure|Thriller          3  Christoph Waltz
# 3                  Action|Thriller          2        Tom Hardy
# 4          Action|Adventure|Sci-Fi          3     Daryl Sabara
#
#         Actor2_Name           Actor3_Name           Director  Year  ...  \
# 0  Joel David Moore             Wes Studi      James Cameron  2009  ...
# ...

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3891 entries, 0 to 3890
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ScreenColor           3889 non-null   object
#  1   Title                 3891 non-null   object
#  2   Genre1                3891 non-null   object
#  3   Genre2                3891 non-null   object
#  4   Genre_Nos             3891 non-null   int64
#  5   Actor1_Name           3888 non-null   object
#  6   Actor2_Name           3886 non-null   object
#  7   Actor3_Name           3881 non-null   object
#  8   Director              3891 non-null   object
#  9   Year                  3891 non-null   int64
#  10  Duration              3890 non-null   float64
#  11  IMDB_Score            3891 non-null   float64
#  12  BudgetMillions        3891 non-null   int64
#  13  GrossMillions         3891 non-null   int64
#  14  Language              3888 non-null   object
# ...

# %%
imdb.describe()
# Out:
#          Genre_Nos         Year     Duration   IMDB_Score  BudgetMillions  \
# count  3891.000000  3891.000000  3890.000000  3891.000000    3.891000e+03
# mean      2.966333  2003.081470   109.896401     6.463506    4.521028e+07
# std       1.185234    10.001352    22.706775     1.056080    2.223895e+08
# min       1.000000  1920.000000    34.000000     1.600000    2.180000e+02
# 25%       2.000000  1999.000000    95.000000     5.900000    1.000000e+07
# 50%       3.000000  2005.000000   106.000000     6.600000    2.400000e+07
# 75%       4.000000  2010.000000   120.000000     7.200000    5.000000e+07
# max       8.000000  2016.000000   330.000000     9.300000    1.221550e+10
#
#        GrossMillions  Facenumber_in_Poster  Actor1_FBLikes  Actor2_FBLikes  \
# count   3.891000e+03           3885.000000     3888.000000     3886.000000
# mean    5.105500e+07              1.379923     7584.675669     1970.656974
# std     6.980248e+07              2.055314    15366.076754     4485.731089
# ...

# %%
imdb.Year = imdb.Year.astype('category')

# %%
imdb.Genre1 = imdb.Genre1.astype('category')

# %%
imdb.Genre2 = imdb.Genre2.astype('category')

# %%
imdb.Title = imdb.Title.astype('category')

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3891 entries, 0 to 3890
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ScreenColor           3889 non-null   object
#  1   Title                 3891 non-null   category
#  2   Genre1                3891 non-null   category
#  3   Genre2                3891 non-null   category
#  4   Genre_Nos             3891 non-null   int64
#  5   Actor1_Name           3888 non-null   object
#  6   Actor2_Name           3886 non-null   object
#  7   Actor3_Name           3881 non-null   object
#  8   Director              3891 non-null   object
#  9   Year                  3891 non-null   category
#  10  Duration              3890 non-null   float64
#  11  IMDB_Score            3891 non-null   float64
#  12  BudgetMillions        3891 non-null   int64
#  13  GrossMillions         3891 non-null   int64
# ...

# %%
warnings.filterwarnings('ignore')

# %%
Reviews = sns.jointplot(data=imdb, x = 'No_CriticReviews', y = 'UserReviews')

# %%
Act1_Mov_FBLikes = sns.jointplot(data=imdb, x = 'Director_FBLikes', y = 'UserReviews')

# %%
Reviews_Genre = sns.lmplot(data=imdb, x='No_CriticReviews', y='UserReviews', \
                 fit_reg=False, hue='Genre1', size=7, aspect=1)

# %%
BudgetGross_Genre = sns.lmplot(data=imdb, x='BudgetMillions', y='GrossMillions', \
                 fit_reg=False, hue='Genre1', size=7, aspect=1)

# %%
list1=list()
for gen in imdb.Genre1.cat.categories:
    list1.append(imdb[imdb.Genre1==gen].BudgetMillions)

h= plt.hist(list1, bins=5, stacked=False, rwidth=1)
